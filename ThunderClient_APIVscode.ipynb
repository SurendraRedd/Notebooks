# %% [markdown]
# <a href="https://colab.research.google.com/github/SurendraRedd/Notebooks/blob/main/ThunderClient_APIVscode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Thunder Client - VS Code Plugin
# ##### Purpose - API Testing light weight Postman
# ##### Features:
# - Collections
# - Tests development
# - Unit Testing
# ##### Vscode Extension - https://marketplace.visualstudio.com/items?itemName=rangav.vscode-thunder-client

# %% [markdown]
# ### Example Rest API
# - https://reqres.in/
# - https://my-json-server.typicode.com/SurendraRedd/Notebooks/coders

# %% [markdown]
# ### Get Request

# %%
from IPython import display
display.Image("./GetRequest.jpg")
#display.Image("https://github.com/SurendraRedd/Notebooks/blob/main/ThunderClient/GetRequest.jpg")

# %% [markdown]
# ### Get Request - Tests

# %%
from IPython import display
display.Image("./GetRequestTests.jpg")

# %% [markdown]
# ### Post Request

# %%
from IPython import display
display.Image("./PostRequest.jpg")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c3147b9a-1437-4d7f-b3a6-141719e97be4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
